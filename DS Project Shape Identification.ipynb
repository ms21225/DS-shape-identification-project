# %% [markdown]
# # Import libraries

# %%
! pip install tensorflow
! pip install opencv-python
! pip install pandas
! pip install numpy 
! pip install matplotlib
# Out:
# Collecting tensorflow
#   Downloading tensorflow-2.14.0-cp39-cp39-win_amd64.whl (2.1 kB)
# Collecting tensorflow-intel==2.14.0
#   Downloading tensorflow_intel-2.14.0-cp39-cp39-win_amd64.whl (284.1 MB)
#      -------------------------------------- 284.1/284.1 MB 2.1 MB/s eta 0:00:00
# Collecting opt-einsum>=2.3.2
#   Downloading opt_einsum-3.3.0-py3-none-any.whl (65 kB)
#      -------------------------------------- 65.5/65.5 kB 708.3 kB/s eta 0:00:00
# Collecting termcolor>=1.1.0
#   Downloading termcolor-2.3.0-py3-none-any.whl (6.9 kB)
# Collecting google-pasta>=0.1.1
#   Downloading google_pasta-0.2.0-py3-none-any.whl (57 kB)
#      ---------------------------------------- 57.5/57.5 kB 3.1 MB/s eta 0:00:00
# Collecting ml-dtypes==0.2.0
#   Downloading ml_dtypes-0.2.0-cp39-cp39-win_amd64.whl (938 kB)
#      -------------------------------------- 938.4/938.4 kB 2.2 MB/s eta 0:00:00
# Collecting absl-py>=1.0.0
#   Downloading absl_py-2.0.0-py3-none-any.whl (130 kB)
#      -------------------------------------- 130.2/130.2 kB 3.9 MB/s eta 0:00:00
# Collecting astunparse>=1.6.0
#   Downloading astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Requirement already satisfied: setuptools in c:\users\91637\downloads\new folder\new folder\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (63.4.1)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\91637\downloads\new folder\new folder\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (3.7.0)
# Collecting tensorboard<2.15,>=2.14
#   Downloading tensorboard-2.14.1-py3-none-any.whl (5.5 MB)
#      ---------------------------------------- 5.5/5.5 MB 1.3 MB/s eta 0:00:00
# Requirement already satisfied: packaging in c:\users\91637\downloads\new folder\new folder\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (21.3)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in c:\users\91637\downloads\new folder\new folder\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (1.14.1)
# Collecting keras<2.15,>=2.14.0
#   Downloading keras-2.14.0-py3-none-any.whl (1.7 MB)
#      ---------------------------------------- 1.7/1.7 MB 1.4 MB/s eta 0:00:00
# Collecting tensorflow-estimator<2.15,>=2.14.0
#   Downloading tensorflow_estimator-2.14.0-py2.py3-none-any.whl (440 kB)
#      ------------------------------------ 440.7/440.7 kB 985.0 kB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\91637\downloads\new folder\new folder\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (4.3.0)
# Collecting grpcio<2.0,>=1.24.3
#   Downloading grpcio-1.59.2-cp39-cp39-win_amd64.whl (3.7 MB)
#      ---------------------------------------- 3.7/3.7 MB 1.3 MB/s eta 0:00:00
# Collecting libclang>=13.0.0
#   Downloading libclang-16.0.6-py2.py3-none-win_amd64.whl (24.4 MB)
#      ---------------------------------------- 24.4/24.4 MB 1.9 MB/s eta 0:00:00
# Collecting numpy>=1.23.5
#   Downloading numpy-1.26.1-cp39-cp39-win_amd64.whl (15.8 MB)
#      ---------------------------------------- 15.8/15.8 MB 1.5 MB/s eta 0:00:00
# Collecting tensorflow-io-gcs-filesystem>=0.23.1
#   Downloading tensorflow_io_gcs_filesystem-0.31.0-cp39-cp39-win_amd64.whl (1.5 MB)
#      ---------------------------------------- 1.5/1.5 MB 738.0 kB/s eta 0:00:00
# Collecting protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3
#   Downloading protobuf-4.25.0-cp39-cp39-win_amd64.whl (413 kB)
#      -------------------------------------- 413.2/413.2 kB 1.3 MB/s eta 0:00:00
# Collecting gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1
#   Downloading gast-0.5.4-py3-none-any.whl (19 kB)
# Requirement already satisfied: six>=1.12.0 in c:\users\91637\downloads\new folder\new folder\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (1.16.0)
# Collecting flatbuffers>=23.5.26
#   Downloading flatbuffers-23.5.26-py2.py3-none-any.whl (26 kB)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\91637\downloads\new folder\new folder\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.14.0->tensorflow) (0.37.1)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\91637\downloads\new folder\new folder\lib\site-packages (from tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (2.0.3)
# Collecting google-auth<3,>=1.6.3
#   Downloading google_auth-2.23.4-py2.py3-none-any.whl (183 kB)
#      -------------------------------------- 183.3/183.3 kB 1.6 MB/s eta 0:00:00
# Collecting tensorboard-data-server<0.8.0,>=0.7.0
#   Downloading tensorboard_data_server-0.7.2-py3-none-any.whl (2.4 kB)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\91637\downloads\new folder\new folder\lib\site-packages (from tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (2.28.1)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\91637\downloads\new folder\new folder\lib\site-packages (from tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (3.3.4)
# Collecting google-auth-oauthlib<1.1,>=0.5
#   Downloading google_auth_oauthlib-1.0.0-py2.py3-none-any.whl (18 kB)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\91637\downloads\new folder\new folder\lib\site-packages (from packaging->tensorflow-intel==2.14.0->tensorflow) (3.0.9)
# Collecting cachetools<6.0,>=2.0.0
#   Downloading cachetools-5.3.2-py3-none-any.whl (9.3 kB)
# Collecting rsa<5,>=3.1.4
#   Downloading rsa-4.9-py3-none-any.whl (34 kB)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\91637\downloads\new folder\new folder\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (0.2.8)
# Collecting requests-oauthlib>=0.7.0
#   Downloading requests_oauthlib-1.3.1-py2.py3-none-any.whl (23 kB)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\91637\downloads\new folder\new folder\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\91637\downloads\new folder\new folder\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (1.26.11)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\91637\downloads\new folder\new folder\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (2022.9.14)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\91637\downloads\new folder\new folder\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (2.0.4)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\91637\downloads\new folder\new folder\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (0.4.8)
# Collecting oauthlib>=3.0.0
#   Downloading oauthlib-3.2.2-py3-none-any.whl (151 kB)
#      -------------------------------------- 151.7/151.7 kB 1.8 MB/s eta 0:00:00
# Installing collected packages: libclang, flatbuffers, termcolor, tensorflow-io-gcs-filesystem, tensorflow-estimator, tensorboard-data-server, rsa, protobuf, oauthlib, numpy, keras, grpcio, google-pasta, gast, cachetools, astunparse, absl-py, requests-oauthlib, opt-einsum, ml-dtypes, google-auth, google-auth-oauthlib, tensorboard, tensorflow-intel, tensorflow
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.21.5
#     Uninstalling numpy-1.21.5:
#       Successfully uninstalled numpy-1.21.5
# Successfully installed absl-py-2.0.0 astunparse-1.6.3 cachetools-5.3.2 flatbuffers-23.5.26 gast-0.5.4 google-auth-2.23.4 google-auth-oauthlib-1.0.0 google-pasta-0.2.0 grpcio-1.59.2 keras-2.14.0 libclang-16.0.6 ml-dtypes-0.2.0 numpy-1.26.1 oauthlib-3.2.2 opt-einsum-3.3.0 protobuf-4.25.0 requests-oauthlib-1.3.1 rsa-4.9 tensorboard-2.14.1 tensorboard-data-server-0.7.2 tensorflow-2.14.0 tensorflow-estimator-2.14.0 tensorflow-intel-2.14.0 tensorflow-io-gcs-filesystem-0.31.0 termcolor-2.3.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# daal4py 2021.6.0 requires daal==2021.4.0, which is not installed.
# scipy 1.9.1 requires numpy<1.25.0,>=1.18.5, but you have numpy 1.26.1 which is incompatible.
# numba 0.55.1 requires numpy<1.22,>=1.18, but you have numpy 1.26.1 which is incompatible.
# Requirement already satisfied: opencv-python in c:\users\91637\downloads\new folder\new folder\lib\site-packages (4.8.0.74)
# Requirement already satisfied: numpy>=1.19.3 in c:\users\91637\downloads\new folder\new folder\lib\site-packages (from opencv-python) (1.26.1)
# Requirement already satisfied: pandas in c:\users\91637\downloads\new folder\new folder\lib\site-packages (1.4.4)
# Requirement already satisfied: pytz>=2020.1 in c:\users\91637\downloads\new folder\new folder\lib\site-packages (from pandas) (2022.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\91637\downloads\new folder\new folder\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: numpy>=1.18.5 in c:\users\91637\downloads\new folder\new folder\lib\site-packages (from pandas) (1.26.1)
# Requirement already satisfied: six>=1.5 in c:\users\91637\downloads\new folder\new folder\lib\site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Requirement already satisfied: numpy in c:\users\91637\downloads\new folder\new folder\lib\site-packages (1.26.1)
# Requirement already satisfied: matplotlib in c:\users\91637\downloads\new folder\new folder\lib\site-packages (3.5.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\91637\downloads\new folder\new folder\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\91637\downloads\new folder\new folder\lib\site-packages (from matplotlib) (21.3)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\91637\downloads\new folder\new folder\lib\site-packages (from matplotlib) (9.2.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\91637\downloads\new folder\new folder\lib\site-packages (from matplotlib) (1.4.2)
# Requirement already satisfied: numpy>=1.17 in c:\users\91637\downloads\new folder\new folder\lib\site-packages (from matplotlib) (1.26.1)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\91637\downloads\new folder\new folder\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\91637\downloads\new folder\new folder\lib\site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\91637\downloads\new folder\new folder\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: six>=1.5 in c:\users\91637\downloads\new folder\new folder\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
import tensorflow as tf
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from random import shuffle
from tensorflow.keras.layers import Conv2D, Flatten, MaxPooling2D, Dense, Dropout
from tensorflow.keras.models import Sequential
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.utils import to_categorical


import cv2

from sklearn.model_selection import train_test_split

# %% [markdown]
# # Reading data

# %%
import os

BASE_DIR = 'C:\\Users\\samar\\Downloads\\archive (2)\\shapes'
shapes = os.listdir(BASE_DIR)
shapes
# Out:
# ['circle', 'square', 'star', 'triangle']

# %%
data = []
target = []
for i, shape in enumerate(shapes):
    path = os.path.join(BASE_DIR, shape)
    for filename in os.listdir(path):
        image = cv2.imread(os.path.join(path , filename),0)
        image = image.reshape(200,200,1)
        data.append(image)
        target.append(i)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12808\306728607.py in <module>
#       1 data = []
#       2 target = []
# ----> 3 for i, shape in enumerate(shapes):
#       4     path = os.path.join(BASE_DIR, shape)
#       5     for filename in os.listdir(path):
#
# NameError: name 'shapes' is not defined

# %% [markdown]
# # Preprocessing

# %%
data = np.array(data)
target = np.array(target)
target = to_categorical(target)

# %%
data.shape, target.shape
# Out:
# ((14970, 200, 200, 1), (14970, 4))

# %%
X_full, X_test, y_full, y_test = train_test_split(data, target, stratify=target, random_state= 42, test_size = 0.25)
X_train, X_val, y_train, y_val = train_test_split(X_full, y_full, stratify=y_full, random_state= 42, test_size = 0.15)

# %% [markdown]
# Let's check some images to see if everything is alright

# %%
def show_images(count, X, y):
    fig, axes =plt.subplots(count//4,4, figsize = (16, count))
    for i, ind in enumerate(np.random.randint(0, X.shape[0] , count)):
        ax = axes[i//4][i%4] 
        ax.imshow(X[ind],cmap = 'gray')
        ax.title.set_text(shapes[np.argmax(y[ind])])
        ax.set_xticks([]) 
        ax.set_yticks([])
show_images(8, X_train, y_train)

# %%
show_images(8, X_val, y_val)

# %%
train_datagen = ImageDataGenerator(
    rotation_range=180,
    width_shift_range=0.2,
    height_shift_range=0.2,
    rescale = 1.0/255,
    horizontal_flip=True,
    vertical_flip=True)

val_datagen = ImageDataGenerator(rescale = 1.0/255)

# %%
X_test = X_test/255.0
X_train = X_train/255.0
X_val = X_val/255.0

# %% [markdown]
# # Modelling

# %%
model = Sequential([
    Conv2D(32, (3,3),strides = 2 ,input_shape = (200,200,1), activation = 'relu'),
    MaxPooling2D(),
    Conv2D(32, (3,3), activation = 'relu'),
    MaxPooling2D(),
    Conv2D(32, (3,3), activation = 'relu'),
    MaxPooling2D(),
    Conv2D(32, (3,3), activation = 'relu'),
    MaxPooling2D(),
    Flatten(),
    Dropout(0.5),
    Dense(128, activation = 'relu'),
    Dropout(0.5),
    Dense(64, activation = 'relu'),
    Dropout(0.5),
    Dense(4, activation = 'softmax')
])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 99, 99, 32)        320
#
#  max_pooling2d (MaxPooling2  (None, 49, 49, 32)        0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 47, 47, 32)        9248
#
#  max_pooling2d_1 (MaxPoolin  (None, 23, 23, 32)        0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 21, 21, 32)        9248
#
#  max_pooling2d_2 (MaxPoolin  (None, 10, 10, 32)        0
#  g2D)
#
#  conv2d_3 (Conv2D)           (None, 8, 8, 32)          9248
#
#  max_pooling2d_3 (MaxPoolin  (None, 4, 4, 32)          0
#  g2D)
#
#  flatten (Flatten)           (None, 512)               0
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense (Dense)               (None, 128)               65664
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  dropout_2 (Dropout)         (None, 64)                0
#
#  dense_2 (Dense)             (None, 4)                 260
#
# =================================================================
# Total params: 102244 (399.39 KB)
# Trainable params: 102244 (399.39 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.compile(loss='categorical_crossentropy', optimizer = 'adam', metrics = ['accuracy'])

history = model.fit(X_train, y_train, epochs = 5, validation_data = (X_val, y_val))
# Out:
# Epoch 1/5
# 299/299 [==============================] - 90s 283ms/step - loss: 0.4962 - accuracy: 0.7727 - val_loss: 0.0053 - val_accuracy: 0.9988
# Epoch 2/5
# 299/299 [==============================] - 81s 271ms/step - loss: 0.0490 - accuracy: 0.9839 - val_loss: 5.0886e-04 - val_accuracy: 1.0000
# Epoch 3/5
# 299/299 [==============================] - 84s 280ms/step - loss: 0.0256 - accuracy: 0.9928 - val_loss: 5.4492e-06 - val_accuracy: 1.0000
# Epoch 4/5
# 299/299 [==============================] - 83s 278ms/step - loss: 0.0174 - accuracy: 0.9941 - val_loss: 3.9613e-05 - val_accuracy: 1.0000
# Epoch 5/5
# 299/299 [==============================] - 83s 277ms/step - loss: 0.0097 - accuracy: 0.9969 - val_loss: 3.7878e-06 - val_accuracy: 1.0000

# %%
metrics = pd.DataFrame(history.history)
plt.plot(metrics)
# Out:
# [<matplotlib.lines.Line2D at 0x164f8d306d0>,
#  <matplotlib.lines.Line2D at 0x164f8d30730>,
#  <matplotlib.lines.Line2D at 0x164f8d30760>,
#  <matplotlib.lines.Line2D at 0x164f8d30850>]

# %%
loss, accuracy = model.evaluate(X_test, y_test)
print('Accuracy is {}%'.format(accuracy*100))
# Out:
# 117/117 [==============================] - 10s 83ms/step - loss: 2.0882e-05 - accuracy: 1.0000
# Accuracy is 100.0%

# %%
def show_images_predicted(count, X, y):
    fig, axes =plt.subplots(count//4,4, figsize = (16, count))
    for i, ind in enumerate(np.random.randint(0, X.shape[0] , count)):
        ax = axes[i//4][i%4] 
        ax.imshow(X[ind],cmap = 'gray')
        res=""
        if y[ind][0]==1:
            res+="circle"
        if y[ind][1]==1:
            res+="square"
        if y[ind][2]==1:
            res="star"
        if y[ind][3]==1:
            res="triangle"
        ax.title.set_text(res)
        ax.set_xticks([]) 
        ax.set_yticks([])

# %%
preds = model.predict(X_test)
show_images_predicted(16,X_test, preds)
# Out:
# 117/117 [==============================] - 11s 82ms/step

# %%
! pip install pickle-mixin
# Out:
# Requirement already satisfied: pickle-mixin in c:\users\samar\anaconda3\lib\site-packages (1.0.2)

# %%
BASE_DIR = r'C:\Users\samar\Downloads\archive (2)\shapes\star'

shapes = os.listdir(BASE_DIR)

data = []

count=12
for filename in shapes:
    image_path = os.path.join(BASE_DIR, filename)
    image = cv2.imread(image_path, 0) 
    image = image.reshape(200, 200, 1)
    data.append(image)

data = np.array(data)
print(data.shape)
data = data/255.0

preds = model.predict(data)

show_images_predicted(count, data, preds)
# Out:
# (3765, 200, 200, 1)
# 118/118 [==============================] - 10s 81ms/step

# %%
import cv2
import time
import numpy as np

# Define an empty list to store image data
data1 = []

# Function to make predictions with the model
def predict_with_model(image_data):
    image_data = np.array(image_data)
    y = model.predict(image_data)
    res=""
    if y[-1][0]==1:
        res+="circle"
    if y[-1][1]==1:
        res+="square"
    if y[-1][2]==1:
        res="star"
    if y[-1][3]==1:
        res="triangle"
    cv2.putText(img_gray, res, (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)

# Open the camera capture
cap = cv2.VideoCapture(0)

# Set the desired frame width and height
frame_width = 200
frame_height = 200
cap.set(3, frame_width)  # 3 corresponds to frame width
cap.set(4, frame_height)  # 4 corresponds to frame height

while True:
    success, img = cap.read()
    
    # Ensure the captured frame is not None
    if img is not None:
        # Convert the image to grayscale
        img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
        
        # Resize the image to 200x200 pixels
        img_gray = cv2.resize(img_gray, (frame_width, frame_height))
        
        # Expand the dimensions to match the desired shape (1, 200, 200, 1)
        img_gray = np.expand_dims(img_gray, axis=-1)
        
        # Append the image to the data1 list
        data1.append(img_gray)
    
        if len(data1) > 0:
            preds = predict_with_model(data1)
            print(preds)
        
        # Display the image
        cv2.imshow("Image", img_gray[:, :, 0])
    
    if cv2.waitKey(1) & 0xFF == ord('q'):  # Press 'q' to exit the loop
        break

# Release the camera
cap.release()
cv2.destroyAllWindows()
# Out:
# 1/1 [==============================] - 0s 28ms/step
# None
# 1/1 [==============================] - 0s 41ms/step
# None
# 1/1 [==============================] - 0s 31ms/step
# None
# 1/1 [==============================] - 0s 32ms/step
# None
# 1/1 [==============================] - 0s 36ms/step
# None
# 1/1 [==============================] - 0s 34ms/step
# None
# 1/1 [==============================] - 0s 37ms/step
# None
# 1/1 [==============================] - 0s 38ms/step
# None
# 1/1 [==============================] - 0s 43ms/step
# None
# 1/1 [==============================] - 0s 41ms/step
# None
# 1/1 [==============================] - 0s 43ms/step
# None
# 1/1 [==============================] - 0s 47ms/step
# None
# 1/1 [==============================] - 0s 44ms/step
# None
# 1/1 [==============================] - 0s 41ms/step
# None
# 1/1 [==============================] - 0s 30ms/step
# None
# 1/1 [==============================] - 0s 49ms/step
# None
# 1/1 [==============================] - 0s 48ms/step
# None
# 1/1 [==============================] - 0s 48ms/step
# None
# 1/1 [==============================] - 0s 55ms/step
# None
# 1/1 [==============================] - 0s 49ms/step
# None
# 1/1 [==============================] - 0s 50ms/step
# None
# 1/1 [==============================] - 0s 31ms/step
# None
# 1/1 [==============================] - 0s 50ms/step
# None
# 1/1 [==============================] - 0s 52ms/step
# None
# 1/1 [==============================] - 0s 54ms/step
# None
# 1/1 [==============================] - 0s 58ms/step
# None
# 1/1 [==============================] - 0s 51ms/step
# None
# 1/1 [==============================] - 0s 54ms/step
# None
# 1/1 [==============================] - 0s 53ms/step
# None
# 1/1 [==============================] - 0s 62ms/step
# None
# 1/1 [==============================] - 0s 63ms/step
# None
# 1/1 [==============================] - 0s 57ms/step
# None
# 2/2 [==============================] - 0s 7ms/step
# None
# 2/2 [==============================] - 0s 6ms/step
# None
# 2/2 [==============================] - 0s 9ms/step
# None
# 2/2 [==============================] - 0s 11ms/step
# None
# 2/2 [==============================] - 0s 17ms/step
# None
# 2/2 [==============================] - 0s 18ms/step
# None
# 2/2 [==============================] - 0s 15ms/step
# None
# 2/2 [==============================] - 0s 15ms/step
# None
# 2/2 [==============================] - 0s 27ms/step
# None
# 2/2 [==============================] - 0s 29ms/step
# None
# 2/2 [==============================] - 0s 21ms/step
# None
# 2/2 [==============================] - 0s 24ms/step
# None
# 2/2 [==============================] - 0s 28ms/step
# None
# 2/2 [==============================] - 0s 31ms/step
# None
# 2/2 [==============================] - 0s 29ms/step
# None
# 2/2 [==============================] - 0s 23ms/step
# None
# 2/2 [==============================] - 0s 36ms/step
# None
# 2/2 [==============================] - 0s 30ms/step
# None
# 2/2 [==============================] - 0s 28ms/step
# None
# 2/2 [==============================] - 0s 32ms/step
# None
# 2/2 [==============================] - 0s 34ms/step
# None
# 2/2 [==============================] - 0s 30ms/step
# None
# 2/2 [==============================] - 0s 28ms/step
# None
# 2/2 [==============================] - 0s 32ms/step
# None
# 2/2 [==============================] - 0s 27ms/step
# None
# 2/2 [==============================] - 0s 34ms/step
# None
# 2/2 [==============================] - 0s 38ms/step
# None
# 2/2 [==============================] - 0s 34ms/step
# None
# 2/2 [==============================] - 0s 33ms/step
# None
# 2/2 [==============================] - 0s 40ms/step
# None
# 2/2 [==============================] - 0s 32ms/step
# None
# 2/2 [==============================] - 0s 38ms/step
# None
# 3/3 [==============================] - 0s 23ms/step
# None
# 3/3 [==============================] - 0s 20ms/step
# None
# 3/3 [==============================] - 0s 21ms/step
# None
# 3/3 [==============================] - 0s 21ms/step
# None
# 3/3 [==============================] - 0s 25ms/step
# None
# 3/3 [==============================] - 0s 28ms/step
# None
# 3/3 [==============================] - 0s 22ms/step
# None
# 3/3 [==============================] - 0s 25ms/step
# None
# 3/3 [==============================] - 0s 29ms/step
# None
# 3/3 [==============================] - 0s 31ms/step
# None
# 3/3 [==============================] - 0s 28ms/step
# None
# 3/3 [==============================] - 0s 25ms/step
# None
# 3/3 [==============================] - 0s 30ms/step
# None
# 3/3 [==============================] - 0s 25ms/step
# None
# 3/3 [==============================] - 0s 33ms/step
# None
# 3/3 [==============================] - 0s 29ms/step
# None
# 3/3 [==============================] - 0s 30ms/step
# None
# 3/3 [==============================] - 0s 34ms/step
# None
# 3/3 [==============================] - 0s 31ms/step
# None
# 3/3 [==============================] - 0s 33ms/step
# None
# 3/3 [==============================] - 0s 36ms/step
# None
# 3/3 [==============================] - 0s 32ms/step
# None
# 3/3 [==============================] - 0s 37ms/step
# None
# 3/3 [==============================] - 0s 33ms/step
# None
# 3/3 [==============================] - 0s 35ms/step
# None
# 3/3 [==============================] - 0s 32ms/step
# None
# 3/3 [==============================] - 0s 37ms/step
# None
# 3/3 [==============================] - 0s 34ms/step
# None
# 3/3 [==============================] - 0s 39ms/step
# None
# 3/3 [==============================] - 0s 33ms/step
# None
# 3/3 [==============================] - 0s 40ms/step
# None
# 3/3 [==============================] - 0s 46ms/step
# None
# 4/4 [==============================] - 0s 26ms/step
# None
# 4/4 [==============================] - 0s 28ms/step
# None
# 4/4 [==============================] - 0s 28ms/step
# None
# 4/4 [==============================] - 0s 27ms/step
# None
# 4/4 [==============================] - 0s 28ms/step
# None
# 4/4 [==============================] - 0s 29ms/step
# None
# 4/4 [==============================] - 0s 28ms/step
# None
# 4/4 [==============================] - 0s 28ms/step
# None
# 4/4 [==============================] - 0s 29ms/step
# None
# 4/4 [==============================] - 0s 27ms/step
# None
# 4/4 [==============================] - 0s 33ms/step
# None
# 4/4 [==============================] - 0s 29ms/step
# None
# 4/4 [==============================] - 0s 28ms/step
# None
# 4/4 [==============================] - 0s 31ms/step
# None
# 4/4 [==============================] - 0s 32ms/step
# None
# 4/4 [==============================] - 0s 31ms/step
# None
# 4/4 [==============================] - 0s 34ms/step
# None
# 4/4 [==============================] - 0s 31ms/step
# None
# 4/4 [==============================] - 0s 35ms/step
# None
# 4/4 [==============================] - 0s 33ms/step
# None
# 4/4 [==============================] - 0s 33ms/step
# None
# 4/4 [==============================] - 0s 33ms/step
# None
# 4/4 [==============================] - 0s 40ms/step
# None
# 4/4 [==============================] - 0s 36ms/step
# None
# 4/4 [==============================] - 0s 35ms/step
# None
# 4/4 [==============================] - 0s 36ms/step
# None
# 4/4 [==============================] - 0s 34ms/step
# None
# 4/4 [==============================] - 0s 35ms/step
# None
# 4/4 [==============================] - 0s 38ms/step
# None
# 4/4 [==============================] - 0s 38ms/step
# None
# 4/4 [==============================] - 0s 37ms/step
# None
# 4/4 [==============================] - 0s 34ms/step
# None
# 5/5 [==============================] - 0s 29ms/step
# None
# 5/5 [==============================] - 0s 28ms/step
# None
# 5/5 [==============================] - 0s 36ms/step
# None
# 5/5 [==============================] - 0s 30ms/step
# None
# 5/5 [==============================] - 0s 29ms/step
# None
# 5/5 [==============================] - 0s 28ms/step
# None
# 5/5 [==============================] - 0s 28ms/step
# None
# 5/5 [==============================] - 0s 30ms/step
# None
# 5/5 [==============================] - 0s 31ms/step
# None
# 5/5 [==============================] - 0s 34ms/step
# None
# 5/5 [==============================] - 0s 33ms/step
# None
# 5/5 [==============================] - 0s 29ms/step
# None
# 5/5 [==============================] - 0s 30ms/step
# None
# 5/5 [==============================] - 0s 32ms/step
# None
# 5/5 [==============================] - 0s 33ms/step
# None
# 5/5 [==============================] - 0s 38ms/step
# None
# 5/5 [==============================] - 0s 36ms/step
# None
# 5/5 [==============================] - 0s 34ms/step
# None
# 5/5 [==============================] - 0s 32ms/step
# None
# 5/5 [==============================] - 0s 31ms/step
# None
# 5/5 [==============================] - 0s 37ms/step
# None
# 5/5 [==============================] - 0s 33ms/step
# None
# 5/5 [==============================] - 0s 34ms/step
# None
# 5/5 [==============================] - 0s 33ms/step
# None
# 5/5 [==============================] - 0s 34ms/step
# None
# 5/5 [==============================] - 0s 34ms/step
# None
# 5/5 [==============================] - 0s 38ms/step
# None
# 5/5 [==============================] - 0s 36ms/step
# None
# 5/5 [==============================] - 0s 34ms/step
# None
# 5/5 [==============================] - 0s 34ms/step
# None
# 5/5 [==============================] - 0s 36ms/step
# None
# 5/5 [==============================] - 0s 35ms/step
# None
# 6/6 [==============================] - 0s 29ms/step
# None
# 6/6 [==============================] - 0s 29ms/step
# None
# 6/6 [==============================] - 0s 33ms/step
# None
# 6/6 [==============================] - 0s 32ms/step
# None
# 6/6 [==============================] - 0s 32ms/step
# None
# 6/6 [==============================] - 0s 30ms/step
# None
# 6/6 [==============================] - 0s 31ms/step
# None
# 6/6 [==============================] - 0s 31ms/step
# None
# 6/6 [==============================] - 0s 33ms/step
# None
# 6/6 [==============================] - 0s 30ms/step
# None
# 6/6 [==============================] - 0s 33ms/step
# None
# 6/6 [==============================] - 0s 31ms/step
# None
# 6/6 [==============================] - 0s 32ms/step
# None
# 6/6 [==============================] - 0s 34ms/step
# None
# 6/6 [==============================] - 0s 32ms/step
# None
# 6/6 [==============================] - 0s 34ms/step
# None
# 6/6 [==============================] - 0s 32ms/step
# None
# 6/6 [==============================] - 0s 34ms/step
# None
# 6/6 [==============================] - 0s 34ms/step
# None
# 6/6 [==============================] - 0s 33ms/step
# None
# 6/6 [==============================] - 0s 34ms/step
# None
